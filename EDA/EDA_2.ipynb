# %% [markdown]
# import some stuff

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro
from scipy.stats import normaltest

# %matplotlib inline
sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#eui_train = pd.read_csv('data/train.csv') 
#eui_train = pd.read_csv('/content/drive/My Drive/DS4Women_project/kaggle_data_code/kaggle_data/train.csv')
eui_train = pd.read_csv("drive/Shareddrives/DS4W-Team/Data/train.csv", header = 0, index_col = "id")
eui_train.shape
# Out:
# (75757, 63)

# %%
print(eui_train['Year_Factor'].unique())
print(eui_train['State_Factor'].unique())
# Out:
# [1 2 3 4 5 6]
# ['State_1' 'State_2' 'State_4' 'State_6' 'State_8' 'State_10' 'State_11']

# %%
df_year1 = eui_train[eui_train['Year_Factor'] == 1]
df_year2 = eui_train[eui_train['Year_Factor'] == 2]
df_year3 = eui_train[eui_train['Year_Factor'] == 3]
df_year4 = eui_train[eui_train['Year_Factor'] == 4]
df_year5 = eui_train[eui_train['Year_Factor'] == 5]
df_year6 = eui_train[eui_train['Year_Factor'] == 6]

df_year_means = eui_train.groupby('Year_Factor').mean()
df_year_counts = eui_train.groupby('Year_Factor').count()

# %%
df_state1 = eui_train[eui_train['State_Factor'] == 'State_1']
df_state2 = eui_train[eui_train['State_Factor'] == 'State_2']
df_state4 = eui_train[eui_train['State_Factor'] == 'State_4']
df_state6 = eui_train[eui_train['State_Factor'] == 'State_6']
df_state8 = eui_train[eui_train['State_Factor'] == 'State_8']
df_state10 = eui_train[eui_train['State_Factor'] == 'State_10']
df_state11 = eui_train[eui_train['State_Factor'] == 'State_11']

df_state_means = eui_train.groupby('State_Factor').mean()
df_state_counts = eui_train.groupby('State_Factor').count()
#print(df_state_means)
#print(df_state_counts)

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,3,1)
df_year1['site_eui'].plot.hist(title='EUI Year 1', bins = 50)
plt.subplot(2,3,2)
df_year2['site_eui'].plot.hist(title='EUI Year 2', bins = 50)
plt.subplot(2,3,3)
df_year3['site_eui'].plot.hist(title='EUI Year 3', bins = 50)
plt.subplot(2,3,4)
df_year4['site_eui'].plot.hist(title='EUI Year 4', bins = 50)
plt.subplot(2,3,5)
df_year5['site_eui'].plot.hist(title='EUI Year 5', bins = 50)
plt.subplot(2,3,6)
df_year6['site_eui'].plot.hist(title='EUI Year 6', bins = 50)

# %%
def plot_regline(x,y):
    m, b = np.polyfit(x,y,1)
    plt.plot(x, m * x + b, color = 'black')

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,3,1).scatter(df_year1['floor_area'], df_year1['site_eui'])
plot_regline(df_year1['floor_area'], df_year1['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.ylabel('EUI')
plt.xlabel('FloorArea Y1')

plt.subplot(2,3,2).scatter(df_year2['floor_area'], df_year2['site_eui'])
plot_regline(df_year2['floor_area'], df_year2['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea Y2')

plt.subplot(2,3,3).scatter(df_year3['floor_area'], df_year3['site_eui'])
plot_regline(df_year3['floor_area'], df_year3['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea Y3')

plt.subplot(2,3,4).scatter(df_year4['floor_area'], df_year4['site_eui'])
plot_regline(df_year4['floor_area'], df_year4['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea Y4')

plt.subplot(2,3,5).scatter(df_year5['floor_area'], df_year5['site_eui'])
plot_regline(df_year5['floor_area'], df_year5['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea Y5')

plt.subplot(2,3,6).scatter(df_year6['floor_area'], df_year6['site_eui'])
plot_regline(df_year6['floor_area'], df_year6['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea Y6')
plt.suptitle('Floor Area by Year')
plt.show()

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,3,1).scatter(df_year1['energy_star_rating'], df_year1['site_eui'])
plt.ylim(0,1000)
plt.ylabel('EUI')
plt.xlabel('EnergyStar Y1')
plt.subplot(2,3,2).scatter(df_year2['energy_star_rating'], df_year2['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar Y2')
plt.subplot(2,3,3).scatter(df_year3['energy_star_rating'], df_year3['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar Y3')
plt.subplot(2,3,4).scatter(df_year4['energy_star_rating'], df_year4['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar Y4')
plt.subplot(2,3,5).scatter(df_year5['energy_star_rating'], df_year5['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar Y5')
plt.subplot(2,3,6).scatter(df_year6['energy_star_rating'], df_year6['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar Y6')
plt.suptitle('Enery Star by Year')
plt.show()

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,3,1).scatter(df_year1['ELEVATION'], df_year1['site_eui'])
plot_regline(df_year1['ELEVATION'], df_year1['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.ylabel('EUI')
plt.xlabel('Elevation Y1')

plt.subplot(2,3,2).scatter(df_year2['ELEVATION'], df_year2['site_eui'])
plot_regline(df_year2['ELEVATION'], df_year2['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation Y2')

plt.subplot(2,3,3).scatter(df_year3['ELEVATION'], df_year3['site_eui'])
plot_regline(df_year3['ELEVATION'], df_year3['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation Y3')

plt.subplot(2,3,4).scatter(df_year4['ELEVATION'], df_year4['site_eui'])
plot_regline(df_year4['ELEVATION'], df_year4['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation Y4')

plt.subplot(2,3,5).scatter(df_year5['ELEVATION'], df_year5['site_eui'])
plot_regline(df_year5['ELEVATION'], df_year5['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation Y5')

plt.subplot(2,3,6).scatter(df_year6['ELEVATION'], df_year6['site_eui'])
plot_regline(df_year6['ELEVATION'], df_year6['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation Y6')
plt.suptitle('Elevation by Year')

plt.show()

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,3,1).scatter(df_year1['avg_temp'], df_year1['site_eui'])
plot_regline(df_year1['avg_temp'], df_year1['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.ylabel('EUI')
plt.xlabel('AvgTemp Y1')

plt.subplot(2,3,2).scatter(df_year2['avg_temp'], df_year2['site_eui'])
plot_regline(df_year2['avg_temp'], df_year2['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp Y2')

plt.subplot(2,3,3).scatter(df_year3['avg_temp'], df_year3['site_eui'])
plot_regline(df_year3['avg_temp'], df_year3['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp Y3')

plt.subplot(2,3,4).scatter(df_year4['avg_temp'], df_year4['site_eui'])
plot_regline(df_year4['avg_temp'], df_year4['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp Y4')

plt.subplot(2,3,5).scatter(df_year5['avg_temp'], df_year5['site_eui'])
plot_regline(df_year5['avg_temp'], df_year5['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp Y5')

plt.subplot(2,3,6).scatter(df_year6['avg_temp'], df_year6['site_eui'])
plot_regline(df_year6['avg_temp'], df_year6['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp Y6')
plt.suptitle('Avg Temp by Year')
plt.show()

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,4,1)
df_state1['site_eui'].plot.hist(title='EUI State 1', bins = 50)
plt.subplot(2,4,2)
df_state2['site_eui'].plot.hist(title='EUI State 2', bins = 50)
plt.subplot(2,4,3)
df_state4['site_eui'].plot.hist(title='EUI State 4', bins = 50)
plt.subplot(2,4,4)
df_state6['site_eui'].plot.hist(title='EUI State 6', bins = 50)
plt.subplot(2,4,5)
df_state8['site_eui'].plot.hist(title='EUI State 8', bins = 50)
plt.subplot(2,4,6)
df_state10['site_eui'].plot.hist(title='EUI State 10', bins = 50)
plt.subplot(2,4,7)
df_state11['site_eui'].plot.hist(title='EUI State 11', bins = 50)

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,4,1).scatter(df_state1['floor_area'], df_state1['site_eui'])
plot_regline(df_state1['floor_area'], df_state1['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.ylabel('EUI')
plt.xlabel('FloorArea S1')

plt.subplot(2,4,2).scatter(df_state2['floor_area'], df_state2['site_eui'])
plot_regline(df_state2['floor_area'], df_state2['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea S2')

plt.subplot(2,4,3).scatter(df_state4['floor_area'], df_state4['site_eui'])
plot_regline(df_state4['floor_area'], df_state4['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea S4')

plt.subplot(2,4,4).scatter(df_state6['floor_area'], df_state6['site_eui'])
plot_regline(df_state6['floor_area'], df_state6['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea S6')

plt.subplot(2,4,5).scatter(df_state8['floor_area'], df_state8['site_eui'])
plot_regline(df_state8['floor_area'], df_state8['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea S8')

plt.subplot(2,4,6).scatter(df_state10['floor_area'], df_state10['site_eui'])
plot_regline(df_state10['floor_area'], df_state10['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea S10')

plt.subplot(2,4,7).scatter(df_state11['floor_area'], df_state11['site_eui'])
plot_regline(df_state11['floor_area'], df_state11['site_eui'])
plt.ylim(0,1000)
plt.xlim(0,6000000)
plt.xlabel('FloorArea S11')
plt.suptitle('Floor Area by State')
plt.show()

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,4,1).scatter(df_state1['energy_star_rating'], df_state1['site_eui'])
plt.ylim(0,1000)
plt.ylabel('EUI')
plt.xlabel('EnergyStar S1')
plt.subplot(2,4,2).scatter(df_state2['energy_star_rating'], df_state2['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar S2')
plt.subplot(2,4,3).scatter(df_state4['energy_star_rating'], df_state4['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar S4')
plt.subplot(2,4,4).scatter(df_state6['energy_star_rating'], df_state6['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar S6')
plt.subplot(2,4,5).scatter(df_state8['energy_star_rating'], df_state8['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar S8')
plt.subplot(2,4,6).scatter(df_state10['energy_star_rating'], df_state10['site_eui'])
plt.xlim(0,100)
plt.ylim(0,1000)
plt.xlabel('EnergyStar S10')
plt.subplot(2,4,7).scatter(df_state11['energy_star_rating'], df_state11['site_eui'])
plt.ylim(0,1000)
plt.xlabel('EnergyStar S11')
plt.suptitle('Energy Star by State')
plt.show()

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,4,1).scatter(df_state1['ELEVATION'], df_state1['site_eui'])
plot_regline(df_state1['ELEVATION'], df_state1['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.ylabel('EUI')
plt.xlabel('Elevation S1')

plt.subplot(2,4,2).scatter(df_state2['ELEVATION'], df_state2['site_eui'])
plot_regline(df_state2['ELEVATION'], df_state2['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation S2')

plt.subplot(2,4,3).scatter(df_state4['ELEVATION'], df_state4['site_eui'])
plot_regline(df_state4['ELEVATION'], df_state4['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation S4')

plt.subplot(2,4,4).scatter(df_state6['ELEVATION'], df_state6['site_eui'])
plot_regline(df_state6['ELEVATION'], df_state6['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation S6')

plt.subplot(2,4,5).scatter(df_state8['ELEVATION'], df_state8['site_eui'])
plot_regline(df_state8['ELEVATION'], df_state8['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation S8')

plt.subplot(2,4,6).scatter(df_state10['ELEVATION'], df_state10['site_eui'])
plot_regline(df_state10['ELEVATION'], df_state10['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation S10')

plt.subplot(2,4,7).scatter(df_state11['ELEVATION'], df_state11['site_eui'])
plot_regline(df_state11['ELEVATION'], df_state11['site_eui'])
plt.xlim(0,2000)
plt.ylim(0,1000)
plt.xlabel('Elevation S11')
plt.suptitle('Elevation by State')
plt.show()

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,4,1).scatter(df_state1['avg_temp'], df_state1['site_eui'])
plot_regline(df_state1['avg_temp'], df_state1['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.ylabel('EUI')
plt.xlabel('AvgTemp S1')

plt.subplot(2,4,2).scatter(df_state2['avg_temp'], df_state2['site_eui'])
plot_regline(df_state2['avg_temp'], df_state2['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp S2')

plt.subplot(2,4,3).scatter(df_state4['avg_temp'], df_state4['site_eui'])
plot_regline(df_state4['avg_temp'], df_state4['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp S4')

plt.subplot(2,4,4).scatter(df_state6['avg_temp'], df_state6['site_eui'])
plot_regline(df_state6['avg_temp'], df_state6['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp S6')

plt.subplot(2,4,5).scatter(df_state8['avg_temp'], df_state8['site_eui'])
plot_regline(df_state8['avg_temp'], df_state8['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp S8')

plt.subplot(2,4,6).scatter(df_state10['avg_temp'], df_state10['site_eui'])
plot_regline(df_state10['avg_temp'], df_state10['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp S10')

plt.subplot(2,4,7).scatter(df_state11['avg_temp'], df_state11['site_eui'])
plot_regline(df_state11['avg_temp'], df_state11['site_eui'])
plt.xlim(40,80)
plt.ylim(0,1000)
plt.xlabel('AvgTemp S11')
plt.suptitle('AvgTemp by State')
plt.show()
